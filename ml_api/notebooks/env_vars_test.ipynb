# %%
import os

# %%
# !uv pip install python-dotenv
# Out:
# Audited 1 package in 5ms

# %%
from dotenv import load_dotenv

# %%
ls
# Out:
# Dockerfile        __init__.py       requirements.txt  uv.lock
# ReadMe.md         notebooks/        scripts/
# TODO.md           pyproject.toml    src/

# %%
load_dotenv("notebooks/.env")
# Out:
# True

# %%
os.environ["DB_URL"]
# Out:
# 'postgresql://neondb_owner:npg_LFzuUHeI8w5s@ep-royal-leaf-a8q3yo6t-pooler.eastus2.azure.neon.tech/neondb?sslmode=require&channel_binding=require'

# %%
os.getenv("DB_URL")
# Out:
# 'postgresql://neondb_owner:npg_LFzuUHeI8w5s@ep-royal-leaf-a8q3yo6t-pooler.eastus2.azure.neon.tech/neondb?sslmode=require&channel_binding=require'
